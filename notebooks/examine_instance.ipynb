# %% [markdown]
# # This notebook examines the DC2 Phosim instance catalogs

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
u = pd.read_csv('/Users/mwiesner/output/output_u.txt',delim_whitespace=True)
g = pd.read_csv('/Users/mwiesner/output/output_g.txt',delim_whitespace=True)
r = pd.read_csv('/Users/mwiesner/output/output_r.txt',delim_whitespace=True)
i = pd.read_csv('/Users/mwiesner/output/output_i.txt',delim_whitespace=True)
z = pd.read_csv('/Users/mwiesner/output/output_z.txt',delim_whitespace=True)
y = pd.read_csv('/Users/mwiesner/output/output_y.txt',delim_whitespace=True)
#ra      dec     mjd     name

# %% [markdown]
# ### Make the plots of MJD

# %%
u_mjd = u['mjd']
u_ra = u['ra']
u_dec = u['dec']
u_id = u.index

scatter = plt.plot(u_id, u_mjd, '.b-') 
plt.title('u-band MJD')
plt.xlabel('Index')
plt.ylabel('MJD')
#plt.ylim(59815,59825)
plt.show()

g_mjd = g['mjd']
g_ra = g['ra']
g_dec = g['dec']
g_id = g.index

scatter = plt.plot(g_id, g_mjd, '.b-') 
plt.title('g-band MJD')
plt.xlabel('Index')
plt.ylabel('MJD')
#plt.ylim(59815,59825)
plt.show()

r_mjd = r['mjd']
r_ra = r['ra']
r_dec = r['dec']
r_id = r.index

scatter = plt.plot(r_id, r_mjd, '.b-') 
plt.title('r-band MJD')
plt.xlabel('Index')
plt.ylabel('MJD')
#plt.ylim(59815,59825)
plt.show()

i_mjd = i['mjd']
i_ia = i['ra']
i_dec = i['dec']
i_id = i.index

scatter = plt.plot(i_id, i_mjd, '.b-') 
plt.title('i-band MJD')
plt.xlabel('Index')
plt.ylabel('MJD')
#plt.ylim(59815,59825)
plt.show()

z_mjd = z['mjd']
z_za = z['ra']
z_dec = z['dec']
z_zd = z.index

scatter = plt.plot(z_zd, z_mjd, '.b-') 
plt.title('z-band MJD')
plt.xlabel('zndex')
plt.ylabel('MJD')
#plt.ylim(59815,59825)
plt.show()

y_mjd = y['mjd']
y_ya = y['ra']
y_dec = y['dec']
y_yd = y.index

scatter = plt.plot(y_yd, y_mjd, '.b-') 
plt.title('y-band MJD')
plt.xlabel('index')
plt.ylabel('MJD')
#plt.ylim(59815,59825)
plt.show()

# %% [markdown]
# ### Make the plots of RA and DEC

# %%
u_mjd = u['mjd']
u_ra = u['ra']
u_dec = u['dec']
u_yd = u.index

scatter = plt.plot(y_ra, y_dec, '.b') 
plt.title('y-band')
plt.xlabel('RA')
plt.ylabel('DEC')
#plt.ylim(59815,59825)
plt.show()

g_mjd = g['mjd']
g_ra = g['ra']
g_dec = g['dec']
g_yd = g.index

scatter = plt.plot(g_ra, g_dec, '.b') 
plt.title('g-band')
plt.xlabel('RA')
plt.ylabel('DEC')
#plt.ylim(59815,59825)
plt.show()

r_mjd = r['mjd']
r_ra = r['ra']
r_dec = r['dec']
r_yd = r.index

scatter = plt.plot(r_ra, r_dec, '.b') 
plt.title('r-band')
plt.xlabel('RA')
plt.ylabel('DEC')
#plt.ylim(59815,59825)
plt.show()

i_mjd = i['mjd']
i_ra = i['ra']
i_dec = i['dec']
i_yd = i.index

scatter = plt.plot(i_ra, i_dec, '.b') 
plt.title('i-band')
plt.xlabel('RA')
plt.ylabel('DEC')
#plt.ylim(59815,59825)
plt.show()

z_mjd = z['mjd']
z_ra = z['ra']
z_dec = z['dec']
z_yd = z.index

scatter = plt.plot(z_ra, z_dec, '.b') 
plt.title('z-band')
plt.xlabel('RA')
plt.ylabel('DEC')
#plt.ylim(59815,59825)
plt.show()

y_mjd = y['mjd']
y_ra = y['ra']
y_dec = y['dec']
y_yd = y.index

scatter = plt.plot(y_ra, y_dec, '.b') 
plt.title('y-band')
plt.xlabel('RA')
plt.ylabel('DEC')
#plt.ylim(59815,59825)
plt.show()
