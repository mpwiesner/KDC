# %%
#import math
#import fitsio 
#import matplotlib.pyplot as plt
#from astropy.visualization import astropy_mpl_style
#from astropy.utils.data import get_pkg_data_filename
from astropy.io import fits

# %%
# !pwd
# Out:
# /data/des80.b/data/mwiesner

# %%
for x in range (1, 8):
    image_file = get_pkg_data_filename("phosim_release/output/"+str(x)+"/lsst_e_99999999_f1_R22_S11_E000.fits")
    image_data = fits.getdata(image_file)
    plt.figure()
    if x == 1:
        plt.xlim(2015, 2045)
        plt.ylim(2065,2095)
    else: 
        plt.xlim(1990, 2020)
        plt.ylim(2020,2050)
    plt.title("Run "+str(x))
    plt.imshow(image_data, cmap='gray',vmin=0, vmax=400)
    plt.colorbar()
    #plt.savefig('star'+str(x)+'.png')
