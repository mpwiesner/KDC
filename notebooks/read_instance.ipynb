# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from astropy.cosmology import FlatLambdaCDM
import matplotlib as mpl
mpl.rcParams['agg.path.chunksize'] = 10000
from matplotlib.backends.backend_pdf import PdfPages
import math 
from numpy.random import random

# %%
def plotter(ra1,dec1):
      #  b=np.loadtxt(namer, dtype=float)
        ra = ra1*(math.pi/180.)
        dec = dec1*(math.pi/180.)
        #ra = 2*np.pi*(random(10000)-0.5)
        #dec = np.arcsin(1.-random(10000)*2.) 
        fig = plt.figure()
        ax = fig.add_subplot(111, projection="aitoff")
        ax.scatter(ra,dec, marker='o', color='r',s=4.2,alpha=0.5)
        xlab = ['14h','16h','18h','20h','22h','0h','2h','4h','6h','8h','10h']
        ax.set_xticklabels(xlab, weight=800)
        ax.grid(color='k', linestyle='solid', linewidth=0.5)
        fig.show() 
      #  pp = PdfPages('aitoff.pdf')
      #  pp.savefig()
      #  pp.close()
        return 0

# %%
header_list = ["object", "id", "ra", "dec", "mag", "sed", "z", "u1", "u2", "u3", "u4", "u5", "model", "x1", "x2","x3","x4","x5","x6","x7","x8","x9","x10"]
data = pd.read_csv('/Users/mwiesner/000000/instCat/star_cat_159479.txt.gz', names=header_list,delim_whitespace=True)
data2 = pd.read_csv('/Users/mwiesner/000000/instCat/star_cat_6826.txt.gz', names=header_list,delim_whitespace=True)

RA1 = data['ra']
DEC1 = data['dec']

RA2 = data2['ra']
DEC2 = data2['dec']

print('max RA1 is ', max(RA1))
print('min RA1 is ', min(RA1))
print('max DEC1 is ', max(DEC1))
print('min DEC1 is ', min(DEC1))

print('max RA2 is ', max(RA2))
print('min RA2 is ', min(RA2))
print('max DEC2 is ', max(DEC2))
print('min DEC2 is ', min(DEC2))
#for col in data.columns:
#    print(col)
# Out:
# max RA1 is  61.34019147463418
# min RA1 is  56.34462054899939
# max DEC1 is  -30.69800192396255
# min DEC1 is  -34.89545141517328
# max RA2 is  59.90912010238755
# min RA2 is  55.06840156650813
# max DEC2 is  -27.72889760576503
# min DEC2 is  -31.92880198399449

# %%
plotter(RA1,DEC1)
# Out:
# <ipython-input-24-0ccfe9d98c09>:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# 0

# %%
scatter = plt.plot(RA1, DEC1, 'go') 
plt.title('RA vs. DEC for first file')
plt.xlabel('RA')
plt.ylabel('DEC')
plt.show()

scatter = plt.plot(RA2, DEC2, 'go') 
plt.title('RA vs. DEC for second file')
plt.xlabel('RA')
plt.ylabel('DEC')
plt.show()
