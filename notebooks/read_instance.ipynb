# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from astropy.cosmology import FlatLambdaCDM
import matplotlib as mpl
mpl.rcParams['agg.path.chunksize'] = 10000
from matplotlib.backends.backend_pdf import PdfPages
import math 
from numpy.random import random
home_dir = '/Users/mwiesner/'

# %%
def plotter(ra1,dec1):
      #  b=np.loadtxt(namer, dtype=float)
        ra = ra1*(math.pi/180.)
        dec = dec1*(math.pi/180.)
        #ra = 2*np.pi*(random(10000)-0.5)
        #dec = np.arcsin(1.-random(10000)*2.) 
        fig = plt.figure()
        ax = fig.add_subplot(111, projection="aitoff")
        ax.scatter(ra,dec, marker='o', color='r',s=4.2,alpha=0.5)
        xlab = ['14h','16h','18h','20h','22h','0h','2h','4h','6h','8h','10h']
        ax.set_xticklabels(xlab, weight=800)
        ax.grid(color='k', linestyle='solid', linewidth=0.5)
        fig.show() 
      #  pp = PdfPages('aitoff.pdf')
      #  pp.savefig()
      #  pp.close()
        return 0

# %%
def plotter(ra1,dec1):
      #  b=np.loadtxt(namer, dtype=float)
        ra = ra1*(math.pi/180.)
        dec = dec1*(math.pi/180.)
        #ra = 2*np.pi*(random(10000)-0.5)
        #dec = np.arcsin(1.-random(10000)*2.) 
        fig = plt.figure()
        ax = fig.add_subplot(111, projection="aitoff")
        ax.scatter(ra,dec, marker='o', color='r',s=4.2,alpha=0.5)
        xlab = ['14h','16h','18h','20h','22h','0h','2h','4h','6h','8h','10h']
        ax.set_xticklabels(xlab, weight=800)
        ax.grid(color='k', linestyle='solid', linewidth=0.5)
        fig.show() 
      #  pp = PdfPages('aitoff.pdf')
      #  pp.savefig()
      #  pp.close()
        return 0

# %% [markdown]
# ## MainSurveyHostedSNPositions

# %%
header_list = ["object", "id", "ra", "dec", "mag", "sed", "z", "u1", "u2", "u3", "u4", "u5", "model", "x1", "x2","x3","x4","x5","x6","x7","x8","x9","x10"]

#File Empty
#data0 = pd.read_csv(home_dir+'000000/instCat/MainSurveyHostedSNPositions_cat_159479.txt.gz', names=header_list,delim_whitespace=True)
data1 = pd.read_csv(home_dir+'000000/instCat/MainSurveyHostedSNPositions_cat_6826.txt.gz', names=header_list,delim_whitespace=True)

#RA0 = data0['ra']
#DEC0 = data0['dec']

RA1 = data1['ra']
DEC1 =data1['dec']

#print('max RA0 is ', max(RA0))
#print('min RA0 is ', min(RA0))
#print('max DEC0 is ', max(DEC0))
#print('min DEC0 is ', min(DEC0))

print('Catalog: MainSurveyHostedSNPositions_cat_6826.txt.gz')
print('max RA1 is ', max(RA1))
print('min RA1 is ', min(RA1))
print('max DEC1 is ', max(DEC1))
print('min DEC1 is ', min(DEC1))
# Out:
# Catalog: MainSurveyHostedSNPositions_cat_6826.txt.gz
# max RA1 is  58.83381574307381
# min RA1 is  55.16369285328487
# max DEC1 is  -27.75579982032481
# min DEC1 is  -30.42538163002386

# %%
#plotter(RA0,DEC0)

plotter(RA1,DEC1)
# Out:
# <ipython-input-10-0ccfe9d98c09>:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# 0

# %%
#scatter = plt.plot(RA0, DEC0, 'go') 
#plt.title('RA vs. DEC')
#plt.xlabel('RA')
#plt.ylabel('DEC')
#plt.show()

scatter = plt.plot(RA1, DEC1, 'go') 
plt.title('RA vs. DEC for MainSurveyHostedSNPositions_cat_6826.txt.gz')
plt.xlabel('RA')
plt.ylabel('DEC')
plt.show()

# %% [markdown]
# ## MainSurvey_hostlessSN

# %%
header_list = ["object", "id", "ra", "dec", "mag", "sed", "z", "u1", "u2", "u3", "u4", "u5", "model", "x1", "x2","x3","x4","x5","x6","x7","x8","x9","x10"]

data2 = pd.read_csv(home_dir+'000000/instCat/MainSurvey_hostlessSN_cat_159479.txt.gz', names=header_list,delim_whitespace=True)
data3 = pd.read_csv(home_dir+'000000/instCat/MainSurvey_hostlessSN_cat_6826.txt.gz', names=header_list,delim_whitespace=True)
data4 = pd.read_csv(home_dir+'000000/instCat/MainSurvey_hostlessSN_highz_cat_159479.txt.gz', names=header_list,delim_whitespace=True)
data5 = pd.read_csv(home_dir+'000000/instCat/MainSurvey_hostlessSN_highz_cat_6826.txt.gz', names=header_list,delim_whitespace=True)

RA2 = data2['ra']
DEC2 = data2['dec']

RA3 = data3['ra']
DEC3 = data3['dec']

RA4 = data4['ra']
DEC4 = data4['dec']

RA5 = data5['ra']
DEC5 = data5['dec']

print('Catalog: MainSurvey_hostlessSN_cat_159479.txt.gz')
print('max RA2 is ', max(RA2))
print('min RA2 is ', min(RA2))
print('max DEC2 is ', max(DEC2))
print('min DEC2 is ', min(DEC2))

print('Catalog: MainSurvey_hostlessSN_cat_6826.txt.gz')
print('max RA3 is ', max(RA3))
print('min RA3 is ', min(RA3))
print('max DEC3 is ', max(DEC3))
print('min DEC3 is ', min(DEC3))

print('Catalog: MainSurvey_hostlessSN_highz_cat_159479.txt.gz')
print('max RA4 is ', max(RA4))
print('min RA4 is ', min(RA4))
print('max DEC4 is ', max(DEC4))
print('min DEC4 is ', min(DEC4))

print('Catalog: MainSurvey_hostlessSN_highz_cat_6826.txt.gz')
print('max RA5 is ', max(RA5))
print('min RA5 is ', min(RA5))
print('max DEC5 is ', max(DEC5))
print('min DEC5 is ', min(DEC5))
# Out:
# Catalog: MainSurvey_hostlessSN_cat_159479.txt.gz
# max RA2 is  57.23201083683504
# min RA2 is  56.6732724568998
# max DEC2 is  -31.31309406814509
# min DEC2 is  -32.16916247366705
# Catalog: MainSurvey_hostlessSN_cat_6826.txt.gz
# max RA3 is  57.50822216677708
# min RA3 is  55.34197909821003
# max DEC3 is  -27.91593053008859
# min DEC3 is  -31.60164129419562
# Catalog: MainSurvey_hostlessSN_highz_cat_159479.txt.gz
# max RA4 is  57.5671913977666
# min RA4 is  56.50118026577162
# max DEC4 is  -31.01976726880024
# min DEC4 is  -32.24697715596516
# Catalog: MainSurvey_hostlessSN_highz_cat_6826.txt.gz
# max RA5 is  57.56300756827797
# min RA5 is  55.11705427347164
# max DEC5 is  -27.76082993937867
# min DEC5 is  -31.82984586394019

# %%
plotter(RA2,DEC2)

plotter(RA3,DEC3)

plotter(RA4,DEC4)

plotter(RA5,DEC5)
# Out:
# <ipython-input-10-0ccfe9d98c09>:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# 0

# %%
scatter = plt.plot(RA2, DEC2, 'go') 
plt.title('RA vs. DEC for MainSurvey_hostlessSN_cat_159479.txt.gz')
plt.xlabel('RA')
plt.ylabel('DEC')
plt.show()

scatter = plt.plot(RA3, DEC3, 'go') 
plt.title('RA vs. DEC for MainSurvey_hostlessSN_cat_6826.txt.gz')
plt.xlabel('RA')
plt.ylabel('DEC')
plt.show()

scatter = plt.plot(RA4, DEC4, 'go') 
plt.title('RA vs. DEC for MainSurvey_hostlessSN_highz_cat_159479.txt.gz')
plt.xlabel('RA')
plt.ylabel('DEC')
plt.show()

scatter = plt.plot(RA5, DEC5, 'go') 
plt.title('RA vs. DEC for MainSurvey_hostlessSN_highz_cat_6826.txt.gz')
plt.xlabel('RA')
plt.ylabel('DEC')
plt.show()

# %% [markdown]
# ## bright_stars

# %%
header_list = ["object", "id", "ra", "dec", "mag", "sed", "z", "u1", "u2", "u3", "u4", "u5", "model", "x1", "x2","x3","x4","x5","x6","x7","x8","x9","x10"]

data6 = pd.read_csv(home_dir+'000000/instCat/bright_stars_159479.txt', names=header_list,delim_whitespace=True)
data7 = pd.read_csv(home_dir+'000000/instCat/bright_stars_6826.txt', names=header_list,delim_whitespace=True)

RA6 = data6['ra']
DEC6 = data6['dec']

RA7 = data7['ra']
DEC7 = data7['dec']

print("For bright stars catalog 1")
print('max RA6 is ', max(RA6))
print('min RA6 is ', min(RA6))
print('max DEC6 is ', max(DEC6))
print('min DEC6 is ', min(DEC6))

print("For bright stars catalog 2")
print('max RA7 is ', max(RA7))
print('min RA7 is ', min(RA7))
print('max DEC7 is ', max(DEC7))
print('min DEC7 is ', min(DEC7))
# Out:
# max RA6 is  61.20907250190863
# min RA6 is  56.48223180321038
# max DEC6 is  -31.17474748516781
# min DEC6 is  -34.8275201955344
# max RA7 is  59.6004411625038
# min RA7 is  55.21847961908531
# max DEC7 is  -27.86572876887704
# min DEC7 is  -31.67617993017375

# %%
plotter(RA6,DEC6)

plotter(RA7,DEC7)
# Out:
# <ipython-input-10-0ccfe9d98c09>:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# 0

# %%
scatter = plt.plot(RA6, DEC6, 'go') 
plt.title('RA vs. DEC')
plt.xlabel('RA')
plt.ylabel('DEC')
plt.show()

scatter = plt.plot(RA7, DEC7, 'go') 
plt.title('RA vs. DEC')
plt.xlabel('RA')
plt.ylabel('DEC')
plt.show()

# %% [markdown]
# ## gal_cat

# %%
header_list = ["object", "id", "ra", "dec", "mag", "sed", "z", "u1", "u2", "u3", "u4", "u5", "model", "x1", "x2","x3","x4","x5","x6","x7","x8","x9","x10"]

data8 = pd.read_csv(home_dir+'000000/instCat/gal_cat_159479.txt.gz', names=header_list,delim_whitespace=True)
data9 = pd.read_csv(home_dir+'000000/instCat/gal_cat_6826.txt.gz', names=header_list,delim_whitespace=True)

RA8 = data8['ra']
DEC8 = data8['dec']

RA9 = data9['ra']
DEC9 = data9['dec']

print('Catalog: gal_cat_159479.txt.gz')
print('max RA8 is ', max(RA8))
print('min RA8 is ', min(RA8))
print('max DEC8 is ', max(DEC8))
print('min DEC8 is ', min(DEC8))

print('Catalog: gal_cat_6826.txt.gz')
print('max RA9 is ', max(RA9))
print('min RA9 is ', min(RA9))
print('max DEC9 is ', max(DEC9))
print('min DEC9 is ', min(DEC9))
#for col in data.columns:
#    print(col)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Catalog: gal_cat_159479.txt.gz
# max RA8 is  58.01865105786287
# min RA8 is  56.43278795607514
# max DEC8 is  -30.82969901037355
# min DEC8 is  -32.27122228851101
# Catalog: gal_cat_6826.txt.gz
# max RA9 is  58.00150607558987
# min RA9 is  55.06723007259853
# max DEC9 is  -27.72896233466438
# min DEC9 is  -31.92889365166543

# %%
plotter(RA8,DEC8)

plotter(RA9,DEC9)
# Out:
# <ipython-input-19-0ccfe9d98c09>:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# 0

# %%
scatter = plt.plot(RA8, DEC8, 'go') 
plt.title('RA vs. DEC for gal_cat_159479.txt.gz')
plt.xlabel('RA')
plt.ylabel('DEC')
plt.show()

scatter = plt.plot(RA9, DEC9, 'go') 
plt.title('RA vs. DEC for gal_cat_6826.txt.gz')
plt.xlabel('RA')
plt.ylabel('DEC')
plt.show()

# %% [markdown]
# ## knots_cat

# %%
#header_list = ["object", "id", "ra", "dec", "mag", "sed", "z", "u1", "u2", "u3", "u4", "u5", "model", "x1", "x2","x3","x4","x5","x6","x7","x8","x9","x10"]

#Files Empty
#data10 = pd.read_csv(home_dir+'000000/instCat/knots_cat_159479.txt', names=header_list,delim_whitespace=True)
#data11 = pd.read_csv(home_dir+'000000/instCat/knots_cat_6826.txt', names=header_list,delim_whitespace=True)

#RA10 = data10['ra']
#DEC10 = data10['dec']

#RA11 = data11['ra']
#DEC11 = data11['dec']

#print('max RA10 is ', max(RA10))
#print('min RA10 is ', min(RA10))
#print('max DEC10 is ', max(DEC10))
#print('min DEC10 is ', min(DEC10))

#print('max RA11 is ', max(RA11))
#print('min RA11 is ', min(RA11))
#print('max DEC11 is ', max(DEC11))
#print('min DEC11 is ', min(DEC11))

# %%
#plotter(RA10,DEC10)

#plotter(RA11,DEC11)

# %%
#scatter = plt.plot(RA10, DEC10, 'go') 
#plt.title('RA vs. DEC for knots_cat_159479.txt')
#plt.xlabel('RA')
#plt.ylabel('DEC')
#plt.show()

#scatter = plt.plot(RA11, DEC11, 'go') 
#plt.title('RA vs. DEC for knots_cat_6826.txt')
#plt.xlabel('RA')
#plt.ylabel('DEC')
#plt.show()

# %% [markdown]
# ## star_cat

# %%
header_list = ["object", "id", "ra", "dec", "mag", "sed", "z", "u1", "u2", "u3", "u4", "u5", "model", "x1", "x2","x3","x4","x5","x6","x7","x8","x9","x10"]

data12 = pd.read_csv(home_dir+'000000/instCat/star_cat_159479.txt.gz', names=header_list,delim_whitespace=True)
data13 = pd.read_csv(home_dir+'000000/instCat/star_cat_6826.txt.gz', names=header_list,delim_whitespace=True)

RA12 = data12['ra']
DEC12 = data12['dec']

RA13 = data13['ra']
DEC13 = data13['dec']

print('max RA12 is ', max(RA12))
print('min RA12 is ', min(RA12))
print('max DEC12 is ', max(DEC12))
print('min DEC12 is ', min(DEC12))

print('max RA13 is ', max(RA13))
print('min RA13 is ', min(RA13))
print('max DEC13 is ', max(DEC13))
print('min DEC13 is ', min(DEC13))
# Out:
# max RA12 is  61.34019147463418
# min RA12 is  56.34462054899939
# max DEC12 is  -30.69800192396255
# min DEC12 is  -34.89545141517328
# max RA13 is  59.90912010238755
# min RA13 is  55.06840156650813
# max DEC13 is  -27.72889760576503
# min DEC13 is  -31.92880198399449

# %%
plotter(RA12,DEC12)

plotter(RA13,DEC13)
# Out:
# <ipython-input-10-0ccfe9d98c09>:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# 0

# %%
scatter = plt.plot(RA12, DEC12, 'go') 
plt.title('RA vs. DEC for star_cat_159479.txt.gz')
plt.xlabel('RA')
plt.ylabel('DEC')
plt.show()

scatter = plt.plot(RA13, DEC13, 'go') 
plt.title('RA vs. DEC for star_cat_6826.txt.gz')
plt.xlabel('RA')
plt.ylabel('DEC')
plt.show()
