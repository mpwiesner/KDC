# %% [markdown]
# ## Initial Setup

# %%
# Initial setup...
import numpy as np
import pandas as pd
from astropy.io import fits
from astropy.table import Table
import fitsio
from scipy import interpolate
import glob
import math
import os
import sys
import os.path
from pathlib import Path
import h5py
import bisect
from astropy.cosmology import FlatLambdaCDM
import argparse
import os.path
from os import path

from astropy.io.fits.verify import VerifyWarning
import warnings
warnings.simplefilter('ignore', category=VerifyWarning)

c = 2.99e10   # speed of light in cm/sec...

# v. 2.6.1 (which works with python 2.7) installed from 
#  https://imageio.readthedocs.io/en/stable/installation.html
import imageio

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## User input

# %%
# Redshift of kilonova...
#z_kn = 0.0099
#z_kn =  0.19759637

# If debug=True, just plot/calculate synthetic mags for the 4.00days past merger KN 
debug=False

#These are the Kasen models we are using.
#This one is fblue
#kasen2 ='/Users/mwiesner/Kasen_Kilonova_Models_2017/systematic_kilonova_model_grid/knova_d1_n10_m0.025_vk0.30_fd1.0_Xlan1e-4.0.h5'
#This one is fred
#kasen1 = '/Users/mwiesner/Kasen_Kilonova_Models_2017/kilonova_models/knova_d1_n10_m0.040_vk0.15_Xlan1e-1.5.h5'
#kasen1 = '/Users/mwiesner/Kasen_Kilonova_Models_2017/systematic_kilonova_model_grid/knova_d1_n10_m0.1_vk0.20_fd1.0_Xlan1e-4.0.h5'
#kasen1 = '/Users/akhalid/Kasen_Kilonova_Models_2017/systematic_kilonova_model_grid/knova_d1_n10_m0.010_vk0.05_fd1.0_Xlan1e-3.0.h5'

kasen2_check = False

#fblue = '/Users/mwiesner/KDC/kasen/knova_d1_n10_m0.030_vk0.05_fd1.0_Xlan1e-3.0.h5'

# Kasen (2017) models directory name:
#kasen_dirname='/data/des40.a/data/dtucker/DESGW_analysis/Kasen_Kilonova_Models_2017/kilonova_models'

#kasen_dirname= kasen_filename
#kasen_filename = "/Users/mwiesner/KDC/notebooks/output/blue_red.csv"

#fblue='/Users/mwiesner/Kasen_Kilonova_Models_2017/systematic_kilonova_model_grid/knova_d1_n10_m0.025_vk0.30_fd1.0_Xlan1e-4.0.h5'
#fred = '/Users/mwiesner/Kasen_Kilonova_Models_2017/kilonova_models/knova_d1_n10_m0.040_vk0.15_Xlan1e-1.5.h5'

#kasen1 = fblue
#kasen2 = fred
#fblue='/Users/mwiesner/Kasen_Kilonova_Models_2017/systematic_kilonova_model_grid/knova_d1_n10_m0.025_vk0.30_fd1.0_Xlan1e-4.0.h5'
#fred = '/Users/mwiesner/Kasen_Kilonova_Models_2017/kilonova_models/knova_d1_n10_m0.040_vk0.15_Xlan1e-1.5.h5'

#a ‘blue’ kilonova (light r-process ejecta with M = 0.025M¤, vk = 0.3c
#and Xlan = 10-4
#) plus a ‘red’ kilonova (heavy r-process ejecta with M = 0.04M¤,
#vk = 0.15c, and Xlan = 10-1.5).

#Exponent of inner density profile = 1
#Exponent of outer density profile = 10
#Ejecta mass is 0.030 solar masses
#kinetic velocity is 0.05c
#
#Lanthanide fraction 3.0 
#naming convention
#d = exponent of inner density profile
#n - exponent of 
#Units of the spectra are ergs/sec/Hz

#divide by 4piD^2 to get an observed flux (ergs/sec/Hz/cm^2)
#kasen_pathname=os.path.join(kasen_dirname,kasen_filename)

# CSV file containing bandpass:
# (Need to add LSST passbands...)
#bandpassFile = '/Users/mwiesner/KDC/kasen/DES_STD_BANDPASSES_Y3A2_ugrizY.test.csv'
#bandpassFile = '/Users/akhalid/KDC/notebooks/input/LSST.dat'
#bandpassFile1 = '/Users/akhalid/KDC/notebooks/input/J_filter'
#bandpassFile2 = '/Users/akhalid/KDC/notebooks/input/H_K_filter'
bandpassFile2 = '/Users/akhalid/KDC/notebooks/input/k_band.dat'
# Comma-separated list with no spaces of passbands to be used...
#bandList = ['u','g','r','i','z','Y']
bandList = ['K']
# bandpass color palette:
#bandpassColors_dict = {'u':'#56b4e9',
#                       'g':'#008060',
 #                      'r':'#ff4000',
 #                      'i':'#850000',
  #                     'z':'#6600cc',
  #                     'y':'#000000',
   #                    'Y':'#000000'
   #                   }
bandpassColors_dict = {'H':'#008060',
                       'K':'#ff4000'
                      }
                      
    
# Verbosity level of output to screen (0,1,2,...)
verbose = 0

# Output directory...
output_dirname = '/Users/akhalid/KDC/kasen'
sed_dirname = '/Users/akhalid/KDC/kasen/SEDs/obj4'
png_dirname = '/Users/akhalid/KDC/kasen/PNGs'

# %% [markdown]
# ## Synthetic Photometry Methods
#
# Based on /data/des40.a/data/dtucker/Y6A1_abscal/calc_abmag.py, which itself made use of some variations of code developed by Keith Bechtol and Eli Rykoff for DES Y3 interstellar reddening corrections...

# %%
# Create an argparse Namespace and run "calc_abmag(args)"...
#  (e.g., run_calc_abmag('u,g,r,i,z,Y', bandpassFile, tempFile, 'LAMBDA', 'Flam', 'Flam', verbose) )

def run_calc_abmag(bandList, bandpassFile, spectrumFile, colname_wave, colname_flam, flux_type, verbose):
    
    args = argparse.Namespace(bandList = bandList, 
                              bandpassFile = bandpassFile, 
                              spectrumFile = spectrumFile, 
                              colname_wave = colname_wave, 
                              colname_flam = colname_flam, 
                              flux_type = flux_type, 
                              verbose = verbose)
    
    if args.verbose > 0: print(args)

    status = calc_abmag(args)
    
     
    return status

    
    
#parser.add_argument('--bandList', help='comma-separated list with no spaces', default='g,r,i,z,Y')
#parser.add_argument('--bandpassFile', help='name of the input plan file', default='DES_STD_BANDPASSES_Y3A2_ugrizY.test.csv')
#parser.add_argument('--spectrumFile', help='name of the input plan file (can be CSV file or a synphot-style FITS file')
#parser.add_argument('--colname_wave', help='name of the wavelength column (in case of a CSV spectrumFile)', default='wave')
#parser.add_argument('--colname_flux', help='name of the flux column (in case of a CSV spectrumFile)', default='flux')
#parser.add_argument('--flux_type', help='type of flux (Flam [ergs/sec/cm**2/Angstrom] or Fnu [ergs/sec/cm**2/Hz])? ', default='Flam')
#parser.add_argument('--verbose', help='verbosity level of output to screen (0,1,2,...)', default=0, type=int)

# %%
# Main method for calculating synthetic AB magnitudes...

def calc_abmag(args):

    #  Extract the bandList...
    bandList = args.bandList
    bandList = bandList.split(',')
    if args.verbose > 0:
        print('bandList: ', bandList)

    #  Extract the name of the bandpassFile...
    bandpassFile = args.bandpassFile
    if os.path.isfile(bandpassFile)==False:
        print("""bandpassFile %s does not exist...""" % (bandpassFile))
        print('Returning with error code 1 now...')
        return 1
    if args.verbose > 0:
        print('bandpassFile: ', bandpassFile)

    #  Extract the name of the spectrum file...
    spectrumFile = args.spectrumFile
    if os.path.isfile(spectrumFile)==False:
        print("""spectrumFile %s does not exist...""" % (spectrumFile))
        print('Returning with error code 1 now...')
        return 1
    if args.verbose > 0:
        print('spectrumFile: ', spectrumFile)

    # Try to determine spectrumFile type (FITS file or CSV file)...
    spectrumType = 'Unknown'
    try:
        hdulist = fits.open(spectrumFile)
        hdulist.close()
        spectrumType = 'FITS'
    except IOError:
        if args.verbose > 2:
            print("""spectrumFile %s is not a FITS file...""" % (spectrumFile))
        try:
            df_test = pd.read_csv(spectrumFile)
            spectrumType = 'CSV'
        except IOError:
            if args.verbose > 2:
                print("""spectrumFile %s is not a CSV file...""" % (spectrumFile))

    # Read in spectrumFile and create a SciPy interpolated function of the spectrum...
    if spectrumType == 'FITS':
        flux,wave_lo,wave_hi = getSpectrumSynphot(spectrumFile, fluxFactor=1.0)
    elif spectrumType == 'CSV':
        flux,wave_lo,wave_hi = getSpectrumCSV(spectrumFile, 
                                              colname_wave=args.colname_wave, colname_flam=args.colname_flam, 
                                              fluxFactor=1.0)
    else:
        print("""Spectrum file %s is of unknown type...""" % (spectrumFile))
        print('Returning with error code 1 now...')
        return 1

    # Read the bandpassFile into a Pandas DataFrame...
    df_resp = pd.read_csv(bandpassFile, comment='#')

    # Check to make sure the spectrumFile covers at least the same wavelength range
    #  as the bandpassFile...
    if ( (wave_lo > df_resp['LAMBDA'].min()) or (wave_hi < df_resp['LAMBDA'].max()) ):
        print("""WARNING:  %s does not cover the full wavelength range of %s""" % (spectrumFile, bandpassFile))
        print('Returning with error code 1 now...')
        return 1

    # Create wavelength_array and flux_array...
    delta_wavelength = 1.0 # angstroms
    wavelength_array = np.arange(wave_lo, wave_hi, delta_wavelength)
    flux_array = flux(wavelength_array)
    

    # If needed, convert flux from flam to fnu...
    if args.flux_type == 'Fnu':
        fnu_array = flux_array
    elif args.flux_type == 'Flam':
        c_kms = 299792.5        # speed of light in km/s
        c_ms = 1000.*c_kms      # speed of light in m/s
        c_as = (1.000e10)*c_ms  # speed of light in Angstroms/sec
        fnu_array = flux_array * wavelength_array * wavelength_array / c_as
    else:
        print("""Flux type %s is unknown...""" % (args.flux_type))
        print('Returning with error code 1 now...')
        return 1


    # Print out header...
    outputLine = ''
    for band in bandList:
        outputLine =  """%s,%s""" % (outputLine, band)
  #  print(outputLine[1:])

    outputLine = ''
    for band in bandList:

        response = interpolate.interp1d(df_resp['LAMBDA'], df_resp[band],
                                        bounds_error=False, fill_value=0.,
                                        kind='linear')
        response_array = response(wavelength_array)

        try:
            abmag = calc_abmag_value(wavelength_array, response_array, fnu_array)
        except Exception:
            abmag = -9999.

        outputLine =  """%s,%.4f""" % (outputLine, abmag)

   # print(outputLine[1:])
    f.write(str(outputLine[1:])+","+"{:.2f}".format(t_kn)+"\n")
    return 0

# %%
# Calculate abmag using the wavelength version of the Fukugita et al. (1996) equation...

def calc_abmag_value(wavelength_array, response_array, fnu_array):

    # Calculate the abmag...
    numerator = np.sum(fnu_array * response_array / wavelength_array)
    denominator = np.sum(response_array / wavelength_array)
    abmag_value = -2.5*math.log10(numerator/denominator) - 48.60

    return abmag_value

# %%
# Return a SciPy interpolation function of a Synphot-style FITS spectrum...
#  (Based on code from Keith Bechtol's synthesize_locus.py.)
# Unless otherwise noted, fluxes are assumed to be Flam and wavelengths
#  are assumed to be in Angstroms...

def getSpectrumSynphot(synphotFileName, fluxFactor=1.0):

    try:

        hdulist = fits.open(synphotFileName)
        t = Table.read(hdulist[1])
        hdulist.close()

    except IOError:

        print("""Could not read %s""" % synphotFileName)
        sys.exit(1)


    wave = t['WAVELENGTH'].data.tolist()
    wave_lo = min(wave)
    wave_hi = max(wave)
    t['FLUX'] = fluxFactor*t['FLUX']
    flam = t['FLUX'].data.tolist()
    flam = t['FLUX'].data.tolist()
    data = {'wavelength': wave, 'flux': flam}

    f = interpolate.interp1d(data['wavelength'], data['flux'],
                             bounds_error=True,
                             kind='linear')

    return f,wave_lo,wave_hi

# %%
# Return a SciPy interpolation function of a CSV-style spectrum...
#  (Based on code from Keith Bechtol's synthesize_locus.py.)
# Unless otherwise noted, fluxes are assumed to be Flam and wavelengths
#  are assumed to be in Angstroms...

def getSpectrumCSV(csvFileName, colname_wave='wave', colname_flam='flux', fluxFactor=1.0):

    try:

        df = pd.read_csv(csvFileName)

    except IOError:

        print("""Could not read %s""" % csvFileName)
        sys.exit(1)


    columnNameList = df.columns.tolist()

    if colname_wave not in columnNameList:
        print("""Column %s not in %s""" % (colname_wave, csvFileName))
        sys.exit(1)

    if colname_flam not in columnNameList:
        print("""Column %s not in %s""" % (colname_wave, csvFileName))
        sys.exit(1)

    wave = df[colname_wave].tolist()
    wave_lo = min(wave)
    wave_hi = max(wave)
    df[colname_flam] = fluxFactor*df[colname_flam]
    flam = df[colname_flam].tolist()
    data = {'wavelength': wave, 'flux': flam}

    f = interpolate.interp1d(data['wavelength'], data['flux'],
                             bounds_error=True,
                             kind='linear')

    return f,wave_lo,wave_hi

# %% [markdown]
# ## Setting up the cosmology

# %%
# Redshift to luminosity distance...
#  Default values of H0 and Omega0 are from Bennett et al. (2014)...
def zToDlum(z, H0=69.6, Om0=0.286):
    from astropy.cosmology import FlatLambdaCDM
    cosmo = FlatLambdaCDM(H0=H0, Om0=Om0)
    # comoving distance...
    Dcom = cosmo.comoving_distance(z)
    # luminosity distance...
    Dlum = (1.+z)*Dcom
    return Dlum


# Mpc_to_cm...
def Mpc_to_cm(Dmpc):
    Dcm = Dmpc*1.00e6*3.086e+18
    return Dcm

# %% [markdown]
# ## Read in bandpass file

# %%
#df_band = pd.read_csv(bandpassFile, comment='#')
#df_band1 = pd.read_csv(bandpassFile1)#, comment='#')
df_band = pd.read_csv(bandpassFile2)#, comment='#')
#df_band1
#print(df_band1['LAMBDA'])

# %% [markdown]
# ## Read in and Plot Kilonova SED...

# %%
#list = pd.read_csv("kasen_sample")
list = pd.read_csv("kasen_list")
model = list["model"]
model
#print(model[0:100])
# Out:
# 0      knova_d1_n10_m0.001_vk0.03_fd1.0_Xlan1e-1.0.h5
# 1      knova_d1_n10_m0.001_vk0.03_fd1.0_Xlan1e-2.0.h5
# 2      knova_d1_n10_m0.001_vk0.03_fd1.0_Xlan1e-3.0.h5
# 3      knova_d1_n10_m0.001_vk0.03_fd1.0_Xlan1e-4.0.h5
# 4      knova_d1_n10_m0.001_vk0.03_fd1.0_Xlan1e-5.0.h5
#                             ...
# 324      knova_d1_n10_m0.1_vk0.30_fd1.0_Xlan1e-2.0.h5
# 325      knova_d1_n10_m0.1_vk0.30_fd1.0_Xlan1e-3.0.h5
# 326      knova_d1_n10_m0.1_vk0.30_fd1.0_Xlan1e-4.0.h5
# 327      knova_d1_n10_m0.1_vk0.30_fd1.0_Xlan1e-5.0.h5
# 328      knova_d1_n10_m0.1_vk0.30_fd1.0_Xlan1e-9.0.h5
# Name: model, Length: 329, dtype: object

# %%
for i in range(0,len(model)):
    print(model[i])
    print("this is model # ",i)
# Out:
# knova_d1_n10_m0.001_vk0.03_fd1.0_Xlan1e-1.0.h5
# this is model #  0
# knova_d1_n10_m0.001_vk0.03_fd1.0_Xlan1e-2.0.h5
# this is model #  1
# knova_d1_n10_m0.001_vk0.03_fd1.0_Xlan1e-3.0.h5
# this is model #  2
# knova_d1_n10_m0.001_vk0.03_fd1.0_Xlan1e-4.0.h5
# this is model #  3
# knova_d1_n10_m0.001_vk0.03_fd1.0_Xlan1e-5.0.h5
# this is model #  4
# knova_d1_n10_m0.001_vk0.03_fd1.0_Xlan1e-9.0.h5
# this is model #  5
# knova_d1_n10_m0.001_vk0.05_fd1.0_Xlan1e-1.0.h5
# this is model #  6
# knova_d1_n10_m0.001_vk0.05_fd1.0_Xlan1e-2.0.h5
# this is model #  7
# knova_d1_n10_m0.001_vk0.05_fd1.0_Xlan1e-3.0.h5
# this is model #  8
# knova_d1_n10_m0.001_vk0.05_fd1.0_Xlan1e-4.0.h5
# this is model #  9
# knova_d1_n10_m0.001_vk0.05_fd1.0_Xlan1e-5.0.h5
# this is model #  10
# knova_d1_n10_m0.001_vk0.05_fd1.0_Xlan1e-9.0.h5
# this is model #  11
# knova_d1_n10_m0.001_vk0.10_fd1.0_Xlan1e-1.0.h5
# this is model #  12
# knova_d1_n10_m0.001_vk0.10_fd1.0_Xlan1e-2.0.h5
# this is model #  13
# knova_d1_n10_m0.001_vk0.10_fd1.0_Xlan1e-3.0.h5
# this is model #  14
# knova_d1_n10_m0.001_vk0.10_fd1.0_Xlan1e-4.0.h5
# this is model #  15
# knova_d1_n10_m0.001_vk0.10_fd1.0_Xlan1e-5.0.h5
# this is model #  16
# knova_d1_n10_m0.001_vk0.10_fd1.0_Xlan1e-9.0.h5
# this is model #  17
# knova_d1_n10_m0.001_vk0.20_fd1.0_Xlan1e-1.0.h5
# this is model #  18
# knova_d1_n10_m0.001_vk0.20_fd1.0_Xlan1e-2.0.h5
# this is model #  19
# knova_d1_n10_m0.001_vk0.20_fd1.0_Xlan1e-3.0.h5
# this is model #  20
# knova_d1_n10_m0.001_vk0.20_fd1.0_Xlan1e-4.0.h5
# this is model #  21
# knova_d1_n10_m0.001_vk0.20_fd1.0_Xlan1e-5.0.h5
# this is model #  22
# knova_d1_n10_m0.001_vk0.20_fd1.0_Xlan1e-9.0.h5
# this is model #  23
# knova_d1_n10_m0.001_vk0.30_fd1.0_Xlan1e-1.0.h5
# this is model #  24
# knova_d1_n10_m0.001_vk0.30_fd1.0_Xlan1e-2.0.h5
# this is model #  25
# knova_d1_n10_m0.001_vk0.30_fd1.0_Xlan1e-3.0.h5
# this is model #  26
# knova_d1_n10_m0.001_vk0.30_fd1.0_Xlan1e-4.0.h5
# this is model #  27
# knova_d1_n10_m0.001_vk0.30_fd1.0_Xlan1e-5.0.h5
# this is model #  28
# knova_d1_n10_m0.001_vk0.30_fd1.0_Xlan1e-9.0.h5
# this is model #  29
# knova_d1_n10_m0.0025_vk0.03_fd1.0_Xlan1e-1.0.h5
# this is model #  30
# knova_d1_n10_m0.0025_vk0.03_fd1.0_Xlan1e-2.0.h5
# this is model #  31
# knova_d1_n10_m0.0025_vk0.03_fd1.0_Xlan1e-3.0.h5
# this is model #  32
# knova_d1_n10_m0.0025_vk0.03_fd1.0_Xlan1e-4.0.h5
# this is model #  33
# knova_d1_n10_m0.0025_vk0.03_fd1.0_Xlan1e-5.0.h5
# this is model #  34
# knova_d1_n10_m0.0025_vk0.03_fd1.0_Xlan1e-9.0.h5
# this is model #  35
# knova_d1_n10_m0.0025_vk0.05_fd1.0_Xlan1e-1.0.h5
# this is model #  36
# knova_d1_n10_m0.0025_vk0.05_fd1.0_Xlan1e-2.0.h5
# this is model #  37
# knova_d1_n10_m0.0025_vk0.05_fd1.0_Xlan1e-3.0.h5
# this is model #  38
# knova_d1_n10_m0.0025_vk0.05_fd1.0_Xlan1e-4.0.h5
# this is model #  39
# knova_d1_n10_m0.0025_vk0.05_fd1.0_Xlan1e-5.0.h5
# this is model #  40
# knova_d1_n10_m0.0025_vk0.05_fd1.0_Xlan1e-9.0.h5
# this is model #  41
# knova_d1_n10_m0.0025_vk0.10_fd1.0_Xlan1e-1.0.h5
# this is model #  42
# knova_d1_n10_m0.0025_vk0.10_fd1.0_Xlan1e-2.0.h5
# this is model #  43
# knova_d1_n10_m0.0025_vk0.10_fd1.0_Xlan1e-3.0.h5
# this is model #  44
# knova_d1_n10_m0.0025_vk0.10_fd1.0_Xlan1e-4.0.h5
# this is model #  45
# knova_d1_n10_m0.0025_vk0.10_fd1.0_Xlan1e-5.0.h5
# this is model #  46
# knova_d1_n10_m0.0025_vk0.10_fd1.0_Xlan1e-9.0.h5
# this is model #  47
# knova_d1_n10_m0.0025_vk0.20_fd1.0_Xlan1e-1.0.h5
# this is model #  48
# knova_d1_n10_m0.0025_vk0.20_fd1.0_Xlan1e-2.0.h5
# this is model #  49
# knova_d1_n10_m0.0025_vk0.20_fd1.0_Xlan1e-3.0.h5
# this is model #  50
# knova_d1_n10_m0.0025_vk0.20_fd1.0_Xlan1e-4.0.h5
# this is model #  51
# knova_d1_n10_m0.0025_vk0.20_fd1.0_Xlan1e-5.0.h5
# this is model #  52
# knova_d1_n10_m0.0025_vk0.20_fd1.0_Xlan1e-9.0.h5
# this is model #  53
# knova_d1_n10_m0.0025_vk0.30_fd1.0_Xlan1e-1.0.h5
# this is model #  54
# knova_d1_n10_m0.0025_vk0.30_fd1.0_Xlan1e-2.0.h5
# this is model #  55
# knova_d1_n10_m0.0025_vk0.30_fd1.0_Xlan1e-3.0.h5
# this is model #  56
# knova_d1_n10_m0.0025_vk0.30_fd1.0_Xlan1e-4.0.h5
# this is model #  57
# knova_d1_n10_m0.0025_vk0.30_fd1.0_Xlan1e-5.0.h5
# this is model #  58
# knova_d1_n10_m0.0025_vk0.30_fd1.0_Xlan1e-9.0.h5
# this is model #  59
# knova_d1_n10_m0.005_vk0.03_fd1.0_Xlan1e-1.0.h5
# this is model #  60
# knova_d1_n10_m0.005_vk0.03_fd1.0_Xlan1e-2.0.h5
# this is model #  61
# knova_d1_n10_m0.005_vk0.03_fd1.0_Xlan1e-3.0.h5
# this is model #  62
# knova_d1_n10_m0.005_vk0.03_fd1.0_Xlan1e-4.0.h5
# this is model #  63
# knova_d1_n10_m0.005_vk0.03_fd1.0_Xlan1e-5.0.h5
# this is model #  64
# knova_d1_n10_m0.005_vk0.03_fd1.0_Xlan1e-9.0.h5
# this is model #  65
# knova_d1_n10_m0.005_vk0.05_fd1.0_Xlan1e-1.0.h5
# this is model #  66
# knova_d1_n10_m0.005_vk0.05_fd1.0_Xlan1e-2.0.h5
# this is model #  67
# knova_d1_n10_m0.005_vk0.05_fd1.0_Xlan1e-3.0.h5
# this is model #  68
# knova_d1_n10_m0.005_vk0.05_fd1.0_Xlan1e-4.0.h5
# this is model #  69
# knova_d1_n10_m0.005_vk0.05_fd1.0_Xlan1e-5.0.h5
# this is model #  70
# knova_d1_n10_m0.005_vk0.05_fd1.0_Xlan1e-9.0.h5
# this is model #  71
# knova_d1_n10_m0.005_vk0.10_fd1.0_Xlan1e-1.0.h5
# this is model #  72
# knova_d1_n10_m0.005_vk0.10_fd1.0_Xlan1e-2.0.h5
# this is model #  73
# knova_d1_n10_m0.005_vk0.10_fd1.0_Xlan1e-3.0.h5
# this is model #  74
# knova_d1_n10_m0.005_vk0.10_fd1.0_Xlan1e-4.0.h5
# this is model #  75
# knova_d1_n10_m0.005_vk0.10_fd1.0_Xlan1e-5.0.h5
# this is model #  76
# knova_d1_n10_m0.005_vk0.10_fd1.0_Xlan1e-9.0.h5
# this is model #  77
# knova_d1_n10_m0.005_vk0.20_fd1.0_Xlan1e-1.0.h5
# this is model #  78
# knova_d1_n10_m0.005_vk0.20_fd1.0_Xlan1e-2.0.h5
# this is model #  79
# knova_d1_n10_m0.005_vk0.20_fd1.0_Xlan1e-3.0.h5
# this is model #  80
# knova_d1_n10_m0.005_vk0.20_fd1.0_Xlan1e-4.0.h5
# this is model #  81
# knova_d1_n10_m0.005_vk0.20_fd1.0_Xlan1e-5.0.h5
# this is model #  82
# knova_d1_n10_m0.005_vk0.20_fd1.0_Xlan1e-9.0.h5
# this is model #  83
# knova_d1_n10_m0.005_vk0.30_fd1.0_Xlan1e-1.0.h5
# this is model #  84
# knova_d1_n10_m0.005_vk0.30_fd1.0_Xlan1e-2.0.h5
# this is model #  85
# knova_d1_n10_m0.005_vk0.30_fd1.0_Xlan1e-3.0.h5
# this is model #  86
# knova_d1_n10_m0.005_vk0.30_fd1.0_Xlan1e-4.0.h5
# this is model #  87
# knova_d1_n10_m0.005_vk0.30_fd1.0_Xlan1e-5.0.h5
# this is model #  88
# knova_d1_n10_m0.005_vk0.30_fd1.0_Xlan1e-9.0.h5
# this is model #  89
# knova_d1_n10_m0.010_vk0.03_fd1.0_Xlan1e-1.0.h5
# this is model #  90
# knova_d1_n10_m0.010_vk0.03_fd1.0_Xlan1e-2.0.h5
# this is model #  91
# knova_d1_n10_m0.010_vk0.03_fd1.0_Xlan1e-3.0.h5
# this is model #  92
# knova_d1_n10_m0.010_vk0.03_fd1.0_Xlan1e-4.0.h5
# this is model #  93
# knova_d1_n10_m0.010_vk0.03_fd1.0_Xlan1e-5.0.h5
# this is model #  94
# knova_d1_n10_m0.010_vk0.03_fd1.0_Xlan1e-9.0.h5
# this is model #  95
# knova_d1_n10_m0.010_vk0.05_fd1.0_Xlan1e-1.0.h5
# this is model #  96
# knova_d1_n10_m0.010_vk0.05_fd1.0_Xlan1e-2.0.h5
# this is model #  97
# knova_d1_n10_m0.010_vk0.05_fd1.0_Xlan1e-3.0.h5
# this is model #  98
# knova_d1_n10_m0.010_vk0.05_fd1.0_Xlan1e-4.0.h5
# this is model #  99
# knova_d1_n10_m0.010_vk0.05_fd1.0_Xlan1e-5.0.h5
# this is model #  100
# knova_d1_n10_m0.010_vk0.05_fd1.0_Xlan1e-9.0.h5
# this is model #  101
# knova_d1_n10_m0.010_vk0.10_fd1.0_Xlan1e-1.0.h5
# this is model #  102
# knova_d1_n10_m0.010_vk0.10_fd1.0_Xlan1e-2.0.h5
# this is model #  103
# knova_d1_n10_m0.010_vk0.10_fd1.0_Xlan1e-3.0.h5
# this is model #  104
# knova_d1_n10_m0.010_vk0.10_fd1.0_Xlan1e-4.0.h5
# this is model #  105
# knova_d1_n10_m0.010_vk0.10_fd1.0_Xlan1e-5.0.h5
# this is model #  106
# knova_d1_n10_m0.010_vk0.10_fd1.0_Xlan1e-9.0.h5
# this is model #  107
# knova_d1_n10_m0.010_vk0.20_fd1.0_Xlan1e-1.0.h5
# this is model #  108
# knova_d1_n10_m0.010_vk0.20_fd1.0_Xlan1e-2.0.h5
# this is model #  109
# knova_d1_n10_m0.010_vk0.20_fd1.0_Xlan1e-3.0.h5
# this is model #  110
# knova_d1_n10_m0.010_vk0.20_fd1.0_Xlan1e-4.0.h5
# this is model #  111
# knova_d1_n10_m0.010_vk0.20_fd1.0_Xlan1e-5.0.h5
# this is model #  112
# knova_d1_n10_m0.010_vk0.20_fd1.0_Xlan1e-9.0.h5
# this is model #  113
# knova_d1_n10_m0.010_vk0.30_fd1.0_Xlan1e-1.0.h5
# this is model #  114
# knova_d1_n10_m0.010_vk0.30_fd1.0_Xlan1e-2.0.h5
# this is model #  115
# knova_d1_n10_m0.010_vk0.30_fd1.0_Xlan1e-3.0.h5
# this is model #  116
# knova_d1_n10_m0.010_vk0.30_fd1.0_Xlan1e-4.0.h5
# this is model #  117
# knova_d1_n10_m0.010_vk0.30_fd1.0_Xlan1e-5.0.h5
# this is model #  118
# knova_d1_n10_m0.010_vk0.30_fd1.0_Xlan1e-9.0.h5
# this is model #  119
# knova_d1_n10_m0.020_vk0.03_fd1.0_Xlan1e-1.0.h5
# this is model #  120
# knova_d1_n10_m0.020_vk0.03_fd1.0_Xlan1e-2.0.h5
# this is model #  121
# knova_d1_n10_m0.020_vk0.03_fd1.0_Xlan1e-3.0.h5
# this is model #  122
# knova_d1_n10_m0.020_vk0.03_fd1.0_Xlan1e-4.0.h5
# this is model #  123
# knova_d1_n10_m0.020_vk0.03_fd1.0_Xlan1e-5.0.h5
# this is model #  124
# knova_d1_n10_m0.020_vk0.03_fd1.0_Xlan1e-9.0.h5
# this is model #  125
# knova_d1_n10_m0.020_vk0.05_fd1.0_Xlan1e-1.0.h5
# this is model #  126
# knova_d1_n10_m0.020_vk0.05_fd1.0_Xlan1e-2.0.h5
# this is model #  127
# knova_d1_n10_m0.020_vk0.05_fd1.0_Xlan1e-3.0.h5
# this is model #  128
# knova_d1_n10_m0.020_vk0.05_fd1.0_Xlan1e-4.0.h5
# this is model #  129
# knova_d1_n10_m0.020_vk0.05_fd1.0_Xlan1e-5.0.h5
# this is model #  130
# knova_d1_n10_m0.020_vk0.05_fd1.0_Xlan1e-9.0.h5
# this is model #  131
# knova_d1_n10_m0.020_vk0.10_fd1.0_Xlan1e-1.0.h5
# this is model #  132
# knova_d1_n10_m0.020_vk0.10_fd1.0_Xlan1e-2.0.h5
# this is model #  133
# knova_d1_n10_m0.020_vk0.10_fd1.0_Xlan1e-3.0.h5
# this is model #  134
# knova_d1_n10_m0.020_vk0.10_fd1.0_Xlan1e-4.0.h5
# this is model #  135
# knova_d1_n10_m0.020_vk0.10_fd1.0_Xlan1e-5.0.h5
# this is model #  136
# knova_d1_n10_m0.020_vk0.10_fd1.0_Xlan1e-9.0.h5
# this is model #  137
# knova_d1_n10_m0.020_vk0.20_fd1.0_Xlan1e-1.0.h5
# this is model #  138
# knova_d1_n10_m0.020_vk0.20_fd1.0_Xlan1e-2.0.h5
# this is model #  139
# knova_d1_n10_m0.020_vk0.20_fd1.0_Xlan1e-3.0.h5
# this is model #  140
# knova_d1_n10_m0.020_vk0.20_fd1.0_Xlan1e-4.0.h5
# this is model #  141
# knova_d1_n10_m0.020_vk0.20_fd1.0_Xlan1e-5.0.h5
# this is model #  142
# knova_d1_n10_m0.020_vk0.20_fd1.0_Xlan1e-9.0.h5
# this is model #  143
# knova_d1_n10_m0.020_vk0.30_fd1.0_Xlan1e-1.0.h5
# this is model #  144
# knova_d1_n10_m0.020_vk0.30_fd1.0_Xlan1e-2.0.h5
# this is model #  145
# knova_d1_n10_m0.020_vk0.30_fd1.0_Xlan1e-3.0.h5
# this is model #  146
# knova_d1_n10_m0.020_vk0.30_fd1.0_Xlan1e-4.0.h5
# this is model #  147
# knova_d1_n10_m0.020_vk0.30_fd1.0_Xlan1e-5.0.h5
# this is model #  148
# knova_d1_n10_m0.020_vk0.30_fd1.0_Xlan1e-9.0.h5
# this is model #  149
# knova_d1_n10_m0.025_vk0.03_fd1.0_Xlan1e-1.0.h5
# this is model #  150
# knova_d1_n10_m0.025_vk0.03_fd1.0_Xlan1e-2.0.h5
# this is model #  151
# knova_d1_n10_m0.025_vk0.03_fd1.0_Xlan1e-3.0.h5
# this is model #  152
# knova_d1_n10_m0.025_vk0.03_fd1.0_Xlan1e-4.0.h5
# this is model #  153
# knova_d1_n10_m0.025_vk0.03_fd1.0_Xlan1e-5.0.h5
# this is model #  154
# knova_d1_n10_m0.025_vk0.03_fd1.0_Xlan1e-9.0.h5
# this is model #  155
# knova_d1_n10_m0.025_vk0.05_fd1.0_Xlan1e-1.0.h5
# this is model #  156
# knova_d1_n10_m0.025_vk0.05_fd1.0_Xlan1e-2.0.h5
# this is model #  157
# knova_d1_n10_m0.025_vk0.05_fd1.0_Xlan1e-3.0.h5
# this is model #  158
# knova_d1_n10_m0.025_vk0.05_fd1.0_Xlan1e-4.0.h5
# this is model #  159
# knova_d1_n10_m0.025_vk0.05_fd1.0_Xlan1e-5.0.h5
# this is model #  160
# knova_d1_n10_m0.025_vk0.05_fd1.0_Xlan1e-9.0.h5
# this is model #  161
# knova_d1_n10_m0.025_vk0.10_fd1.0_Xlan1e-1.0.h5
# this is model #  162
# knova_d1_n10_m0.025_vk0.10_fd1.0_Xlan1e-2.0.h5
# this is model #  163
# knova_d1_n10_m0.025_vk0.10_fd1.0_Xlan1e-3.0.h5
# this is model #  164
# knova_d1_n10_m0.025_vk0.10_fd1.0_Xlan1e-4.0.h5
# this is model #  165
# knova_d1_n10_m0.025_vk0.10_fd1.0_Xlan1e-5.0.h5
# this is model #  166
# knova_d1_n10_m0.025_vk0.10_fd1.0_Xlan1e-9.0.h5
# this is model #  167
# knova_d1_n10_m0.025_vk0.20_fd1.0_Xlan1e-1.0.h5
# this is model #  168
# knova_d1_n10_m0.025_vk0.20_fd1.0_Xlan1e-2.0.h5
# this is model #  169
# knova_d1_n10_m0.025_vk0.20_fd1.0_Xlan1e-3.0.h5
# this is model #  170
# knova_d1_n10_m0.025_vk0.20_fd1.0_Xlan1e-4.0.h5
# this is model #  171
# knova_d1_n10_m0.025_vk0.20_fd1.0_Xlan1e-5.0.h5
# this is model #  172
# knova_d1_n10_m0.025_vk0.20_fd1.0_Xlan1e-9.0.h5
# this is model #  173
# knova_d1_n10_m0.025_vk0.30_fd1.0_Xlan1e-1.0.h5
# this is model #  174
# knova_d1_n10_m0.025_vk0.30_fd1.0_Xlan1e-2.0.h5
# this is model #  175
# knova_d1_n10_m0.025_vk0.30_fd1.0_Xlan1e-3.0.h5
# this is model #  176
# knova_d1_n10_m0.025_vk0.30_fd1.0_Xlan1e-4.0.h5
# this is model #  177
# knova_d1_n10_m0.025_vk0.30_fd1.0_Xlan1e-5.0.h5
# this is model #  178
# knova_d1_n10_m0.025_vk0.30_fd1.0_Xlan1e-9.0.h5
# this is model #  179
# knova_d1_n10_m0.030_vk0.03_fd1.0_Xlan1e-1.0.h5
# this is model #  180
# knova_d1_n10_m0.030_vk0.03_fd1.0_Xlan1e-2.0.h5
# this is model #  181
# knova_d1_n10_m0.030_vk0.03_fd1.0_Xlan1e-3.0.h5
# this is model #  182
# knova_d1_n10_m0.030_vk0.03_fd1.0_Xlan1e-4.0.h5
# this is model #  183
# knova_d1_n10_m0.030_vk0.03_fd1.0_Xlan1e-5.0.h5
# this is model #  184
# knova_d1_n10_m0.030_vk0.03_fd1.0_Xlan1e-9.0.h5
# this is model #  185
# knova_d1_n10_m0.030_vk0.05_fd1.0_Xlan1e-1.0.h5
# this is model #  186
# knova_d1_n10_m0.030_vk0.05_fd1.0_Xlan1e-2.0.h5
# this is model #  187
# knova_d1_n10_m0.030_vk0.05_fd1.0_Xlan1e-3.0.h5
# this is model #  188
# knova_d1_n10_m0.030_vk0.05_fd1.0_Xlan1e-4.0.h5
# this is model #  189
# knova_d1_n10_m0.030_vk0.05_fd1.0_Xlan1e-5.0.h5
# this is model #  190
# knova_d1_n10_m0.030_vk0.05_fd1.0_Xlan1e-9.0.h5
# this is model #  191
# knova_d1_n10_m0.030_vk0.10_fd1.0_Xlan1e-1.0.h5
# this is model #  192
# knova_d1_n10_m0.030_vk0.10_fd1.0_Xlan1e-2.0.h5
# this is model #  193
# knova_d1_n10_m0.030_vk0.10_fd1.0_Xlan1e-3.0.h5
# this is model #  194
# knova_d1_n10_m0.030_vk0.10_fd1.0_Xlan1e-4.0.h5
# this is model #  195
# knova_d1_n10_m0.030_vk0.10_fd1.0_Xlan1e-5.0.h5
# this is model #  196
# knova_d1_n10_m0.030_vk0.10_fd1.0_Xlan1e-9.0.h5
# this is model #  197
# knova_d1_n10_m0.030_vk0.20_fd1.0_Xlan1e-1.0.h5
# this is model #  198
# knova_d1_n10_m0.030_vk0.20_fd1.0_Xlan1e-2.0.h5
# this is model #  199
# knova_d1_n10_m0.030_vk0.20_fd1.0_Xlan1e-3.0.h5
# this is model #  200
# knova_d1_n10_m0.030_vk0.20_fd1.0_Xlan1e-4.0.h5
# this is model #  201
# knova_d1_n10_m0.030_vk0.20_fd1.0_Xlan1e-5.0.h5
# this is model #  202
# knova_d1_n10_m0.030_vk0.20_fd1.0_Xlan1e-9.0.h5
# this is model #  203
# knova_d1_n10_m0.030_vk0.30_fd1.0_Xlan1e-1.0.h5
# this is model #  204
# knova_d1_n10_m0.030_vk0.30_fd1.0_Xlan1e-2.0.h5
# this is model #  205
# knova_d1_n10_m0.030_vk0.30_fd1.0_Xlan1e-3.0.h5
# this is model #  206
# knova_d1_n10_m0.030_vk0.30_fd1.0_Xlan1e-4.0.h5
# this is model #  207
# knova_d1_n10_m0.030_vk0.30_fd1.0_Xlan1e-5.0.h5
# this is model #  208
# knova_d1_n10_m0.030_vk0.30_fd1.0_Xlan1e-9.0.h5
# this is model #  209
# knova_d1_n10_m0.040_vk0.03_fd1.0_Xlan1e-1.0.h5
# this is model #  210
# knova_d1_n10_m0.040_vk0.03_fd1.0_Xlan1e-2.0.h5
# this is model #  211
# knova_d1_n10_m0.040_vk0.03_fd1.0_Xlan1e-3.0.h5
# this is model #  212
# knova_d1_n10_m0.040_vk0.03_fd1.0_Xlan1e-4.0.h5
# this is model #  213
# knova_d1_n10_m0.040_vk0.03_fd1.0_Xlan1e-5.0.h5
# this is model #  214
# knova_d1_n10_m0.040_vk0.03_fd1.0_Xlan1e-9.0.h5
# this is model #  215
# knova_d1_n10_m0.040_vk0.05_fd1.0_Xlan1e-1.0.h5
# this is model #  216
# knova_d1_n10_m0.040_vk0.05_fd1.0_Xlan1e-2.0.h5
# this is model #  217
# knova_d1_n10_m0.040_vk0.05_fd1.0_Xlan1e-3.0.h5
# this is model #  218
# knova_d1_n10_m0.040_vk0.05_fd1.0_Xlan1e-4.0.h5
# this is model #  219
# knova_d1_n10_m0.040_vk0.05_fd1.0_Xlan1e-5.0.h5
# this is model #  220
# knova_d1_n10_m0.040_vk0.05_fd1.0_Xlan1e-9.0.h5
# this is model #  221
# knova_d1_n10_m0.040_vk0.10_fd1.0_Xlan1e-1.0.h5
# this is model #  222
# knova_d1_n10_m0.040_vk0.10_fd1.0_Xlan1e-2.0.h5
# this is model #  223
# knova_d1_n10_m0.040_vk0.10_fd1.0_Xlan1e-3.0.h5
# this is model #  224
# knova_d1_n10_m0.040_vk0.10_fd1.0_Xlan1e-4.0.h5
# this is model #  225
# knova_d1_n10_m0.040_vk0.10_fd1.0_Xlan1e-5.0.h5
# this is model #  226
# knova_d1_n10_m0.040_vk0.10_fd1.0_Xlan1e-9.0.h5
# this is model #  227
# knova_d1_n10_m0.040_vk0.20_fd1.0_Xlan1e-1.0.h5
# this is model #  228
# knova_d1_n10_m0.040_vk0.20_fd1.0_Xlan1e-2.0.h5
# this is model #  229
# knova_d1_n10_m0.040_vk0.20_fd1.0_Xlan1e-3.0.h5
# this is model #  230
# knova_d1_n10_m0.040_vk0.20_fd1.0_Xlan1e-4.0.h5
# this is model #  231
# knova_d1_n10_m0.040_vk0.20_fd1.0_Xlan1e-5.0.h5
# this is model #  232
# knova_d1_n10_m0.040_vk0.20_fd1.0_Xlan1e-9.0.h5
# this is model #  233
# knova_d1_n10_m0.040_vk0.30_fd1.0_Xlan1e-1.0.h5
# this is model #  234
# knova_d1_n10_m0.040_vk0.30_fd1.0_Xlan1e-2.0.h5
# this is model #  235
# knova_d1_n10_m0.040_vk0.30_fd1.0_Xlan1e-3.0.h5
# this is model #  236
# knova_d1_n10_m0.040_vk0.30_fd1.0_Xlan1e-4.0.h5
# this is model #  237
# knova_d1_n10_m0.040_vk0.30_fd1.0_Xlan1e-5.0.h5
# this is model #  238
# knova_d1_n10_m0.040_vk0.30_fd1.0_Xlan1e-9.0.h5
# this is model #  239
# knova_d1_n10_m0.050_vk0.03_fd1.0_Xlan1e-1.0.h5
# this is model #  240
# knova_d1_n10_m0.050_vk0.03_fd1.0_Xlan1e-2.0.h5
# this is model #  241
# knova_d1_n10_m0.050_vk0.03_fd1.0_Xlan1e-3.0.h5
# this is model #  242
# knova_d1_n10_m0.050_vk0.03_fd1.0_Xlan1e-4.0.h5
# this is model #  243
# knova_d1_n10_m0.050_vk0.03_fd1.0_Xlan1e-5.0.h5
# this is model #  244
# knova_d1_n10_m0.050_vk0.03_fd1.0_Xlan1e-9.0.h5
# this is model #  245
# knova_d1_n10_m0.050_vk0.05_fd1.0_Xlan1e-1.0.h5
# this is model #  246
# knova_d1_n10_m0.050_vk0.05_fd1.0_Xlan1e-2.0.h5
# this is model #  247
# knova_d1_n10_m0.050_vk0.05_fd1.0_Xlan1e-3.0.h5
# this is model #  248
# knova_d1_n10_m0.050_vk0.05_fd1.0_Xlan1e-4.0.h5
# this is model #  249
# knova_d1_n10_m0.050_vk0.05_fd1.0_Xlan1e-5.0.h5
# this is model #  250
# knova_d1_n10_m0.050_vk0.05_fd1.0_Xlan1e-9.0.h5
# this is model #  251
# knova_d1_n10_m0.050_vk0.10_fd1.0_Xlan1e-1.0.h5
# this is model #  252
# knova_d1_n10_m0.050_vk0.10_fd1.0_Xlan1e-2.0.h5
# this is model #  253
# knova_d1_n10_m0.050_vk0.10_fd1.0_Xlan1e-3.0.h5
# this is model #  254
# knova_d1_n10_m0.050_vk0.10_fd1.0_Xlan1e-4.0.h5
# this is model #  255
# knova_d1_n10_m0.050_vk0.10_fd1.0_Xlan1e-5.0.h5
# this is model #  256
# knova_d1_n10_m0.050_vk0.10_fd1.0_Xlan1e-9.0.h5
# this is model #  257
# knova_d1_n10_m0.050_vk0.20_fd1.0_Xlan1e-1.0.h5
# this is model #  258
# knova_d1_n10_m0.050_vk0.20_fd1.0_Xlan1e-2.0.h5
# this is model #  259
# knova_d1_n10_m0.050_vk0.20_fd1.0_Xlan1e-3.0.h5
# this is model #  260
# knova_d1_n10_m0.050_vk0.20_fd1.0_Xlan1e-4.0.h5
# this is model #  261
# knova_d1_n10_m0.050_vk0.20_fd1.0_Xlan1e-5.0.h5
# this is model #  262
# knova_d1_n10_m0.050_vk0.20_fd1.0_Xlan1e-9.0.h5
# this is model #  263
# knova_d1_n10_m0.050_vk0.30_fd1.0_Xlan1e-1.0.h5
# this is model #  264
# knova_d1_n10_m0.050_vk0.30_fd1.0_Xlan1e-2.0.h5
# this is model #  265
# knova_d1_n10_m0.050_vk0.30_fd1.0_Xlan1e-3.0.h5
# this is model #  266
# knova_d1_n10_m0.050_vk0.30_fd1.0_Xlan1e-4.0.h5
# this is model #  267
# knova_d1_n10_m0.050_vk0.30_fd1.0_Xlan1e-5.0.h5
# this is model #  268
# knova_d1_n10_m0.050_vk0.30_fd1.0_Xlan1e-9.0.h5
# this is model #  269
# knova_d1_n10_m0.075_vk0.03_fd1.0_Xlan1e-1.0.h5
# this is model #  270
# knova_d1_n10_m0.075_vk0.03_fd1.0_Xlan1e-2.0.h5
# this is model #  271
# knova_d1_n10_m0.075_vk0.03_fd1.0_Xlan1e-3.0.h5
# this is model #  272
# knova_d1_n10_m0.075_vk0.03_fd1.0_Xlan1e-4.0.h5
# this is model #  273
# knova_d1_n10_m0.075_vk0.03_fd1.0_Xlan1e-5.0.h5
# this is model #  274
# knova_d1_n10_m0.075_vk0.03_fd1.0_Xlan1e-9.0.h5
# this is model #  275
# knova_d1_n10_m0.075_vk0.05_fd1.0_Xlan1e-1.0.h5
# this is model #  276
# knova_d1_n10_m0.075_vk0.05_fd1.0_Xlan1e-2.0.h5
# this is model #  277
# knova_d1_n10_m0.075_vk0.05_fd1.0_Xlan1e-3.0.h5
# this is model #  278
# knova_d1_n10_m0.075_vk0.05_fd1.0_Xlan1e-4.0.h5
# this is model #  279
# knova_d1_n10_m0.075_vk0.05_fd1.0_Xlan1e-5.0.h5
# this is model #  280
# knova_d1_n10_m0.075_vk0.05_fd1.0_Xlan1e-9.0.h5
# this is model #  281
# knova_d1_n10_m0.075_vk0.10_fd1.0_Xlan1e-1.0.h5
# this is model #  282
# knova_d1_n10_m0.075_vk0.10_fd1.0_Xlan1e-2.0.h5
# this is model #  283
# knova_d1_n10_m0.075_vk0.10_fd1.0_Xlan1e-3.0.h5
# this is model #  284
# knova_d1_n10_m0.075_vk0.10_fd1.0_Xlan1e-4.0.h5
# this is model #  285
# knova_d1_n10_m0.075_vk0.10_fd1.0_Xlan1e-5.0.h5
# this is model #  286
# knova_d1_n10_m0.075_vk0.10_fd1.0_Xlan1e-9.0.h5
# this is model #  287
# knova_d1_n10_m0.075_vk0.20_fd1.0_Xlan1e-1.0.h5
# this is model #  288
# knova_d1_n10_m0.075_vk0.20_fd1.0_Xlan1e-2.0.h5
# this is model #  289
# knova_d1_n10_m0.075_vk0.20_fd1.0_Xlan1e-3.0.h5
# this is model #  290
# knova_d1_n10_m0.075_vk0.20_fd1.0_Xlan1e-4.0.h5
# this is model #  291
# knova_d1_n10_m0.075_vk0.20_fd1.0_Xlan1e-5.0.h5
# this is model #  292
# knova_d1_n10_m0.075_vk0.20_fd1.0_Xlan1e-9.0.h5
# this is model #  293
# knova_d1_n10_m0.075_vk0.30_fd1.0_Xlan1e-1.0.h5
# this is model #  294
# knova_d1_n10_m0.075_vk0.30_fd1.0_Xlan1e-2.0.h5
# this is model #  295
# knova_d1_n10_m0.075_vk0.30_fd1.0_Xlan1e-3.0.h5
# this is model #  296
# knova_d1_n10_m0.075_vk0.30_fd1.0_Xlan1e-4.0.h5
# this is model #  297
# knova_d1_n10_m0.075_vk0.30_fd1.0_Xlan1e-5.0.h5
# this is model #  298
# knova_d1_n10_m0.075_vk0.30_fd1.0_Xlan1e-9.0.h5
# this is model #  299
# knova_d1_n10_m0.1_vk0.03_fd1.0_Xlan1e-1.0.h5
# this is model #  300
# knova_d1_n10_m0.1_vk0.03_fd1.0_Xlan1e-2.0.h5
# this is model #  301
# knova_d1_n10_m0.1_vk0.03_fd1.0_Xlan1e-3.0.h5
# this is model #  302
# knova_d1_n10_m0.1_vk0.03_fd1.0_Xlan1e-4.0.h5
# this is model #  303
# knova_d1_n10_m0.1_vk0.03_fd1.0_Xlan1e-5.0.h5
# this is model #  304
# knova_d1_n10_m0.1_vk0.03_fd1.0_Xlan1e-9.0.h5
# this is model #  305
# knova_d1_n10_m0.1_vk0.05_fd1.0_Xlan1e-1.0.h5
# this is model #  306
# knova_d1_n10_m0.1_vk0.05_fd1.0_Xlan1e-2.0.h5
# this is model #  307
# knova_d1_n10_m0.1_vk0.05_fd1.0_Xlan1e-3.0.h5
# this is model #  308
# knova_d1_n10_m0.1_vk0.05_fd1.0_Xlan1e-4.0.h5
# this is model #  309
# knova_d1_n10_m0.1_vk0.05_fd1.0_Xlan1e-5.0.h5
# this is model #  310
# knova_d1_n10_m0.1_vk0.05_fd1.0_Xlan1e-9.0.h5
# this is model #  311
# knova_d1_n10_m0.1_vk0.10_fd1.0_Xlan1e-1.0.h5
# this is model #  312
# knova_d1_n10_m0.1_vk0.10_fd1.0_Xlan1e-2.0.h5
# this is model #  313
# knova_d1_n10_m0.1_vk0.10_fd1.0_Xlan1e-3.0.h5
# this is model #  314
# knova_d1_n10_m0.1_vk0.10_fd1.0_Xlan1e-4.0.h5
# this is model #  315
# knova_d1_n10_m0.1_vk0.10_fd1.0_Xlan1e-5.0.h5
# this is model #  316
# knova_d1_n10_m0.1_vk0.10_fd1.0_Xlan1e-9.0.h5
# this is model #  317
# knova_d1_n10_m0.1_vk0.20_fd1.0_Xlan1e-1.0.h5
# this is model #  318
# knova_d1_n10_m0.1_vk0.20_fd1.0_Xlan1e-2.0.h5
# this is model #  319
# knova_d1_n10_m0.1_vk0.20_fd1.0_Xlan1e-3.0.h5
# this is model #  320
# knova_d1_n10_m0.1_vk0.20_fd1.0_Xlan1e-4.0.h5
# this is model #  321
# knova_d1_n10_m0.1_vk0.20_fd1.0_Xlan1e-5.0.h5
# this is model #  322
# knova_d1_n10_m0.1_vk0.20_fd1.0_Xlan1e-9.0.h5
# this is model #  323
# knova_d1_n10_m0.1_vk0.30_fd1.0_Xlan1e-2.0.h5
# this is model #  324
# knova_d1_n10_m0.1_vk0.30_fd1.0_Xlan1e-3.0.h5
# this is model #  325
# knova_d1_n10_m0.1_vk0.30_fd1.0_Xlan1e-4.0.h5
# this is model #  326
# knova_d1_n10_m0.1_vk0.30_fd1.0_Xlan1e-5.0.h5
# this is model #  327
# knova_d1_n10_m0.1_vk0.30_fd1.0_Xlan1e-9.0.h5
# this is model #  328

# %% [markdown]
# model = list["model"]
#
# abmag_value
#
# while m < 18

# %%
#This turns on plotting if set equal to True
plotter = False
bandpassFile = bandpassFile2
for i in range(0,len(model)):
    print("working on model ",i)
    print(model[i])

    kasen1 = "/Users/akhalid/Kasen_Kilonova_Models_2017/systematic_kilonova_model_grid/"+model[i]
    Dlum = zToDlum(z_kn)
    Dlum_cm = Mpc_to_cm(Dlum)

    #This is the output light curve file
    myfile = Path("output/light_curve_"+str(i)+".txt")
    #This is the output file that contains the time after GW event
    #myfile2 = Path("output/time.txt")

    #I did this so i
    if myfile.exists():
        # !rm output/light_curve_str(i).txt
    #if myfile2.exists():
    #    !rm output/time.txt

    f = open("output/light_curve_"+str(i)+".txt", "w")
    #f.write('u,g,r,i,z,y,time\n')
    f.write('K,time\n')
    #f2 = open("output/time.txt", "w")
    #f2.write("day_after \n")

    # open Kasen model file
    #fin    = h5py.File(kasen_pathname,'r')

    #RED FILE
    # open model file
    fin    = h5py.File(kasen1,'r')
    # frequency in Hz
    nu    = np.array(fin['nu'],dtype='d')
    # array of time in seconds
    times = np.array(fin['time'])
    # convert time to days
    times = times/3600.0/24.0

    fine = np.where((times > 0.1) & (times < 12.1))
    timer = times[fine]

    # specific luminosity (ergs/s/Hz)
    # this is a 2D array, Lnu[times][nu]
    Lnu_all   = np.array(fin['Lnu'],dtype='d')
    #_____________________________________________
    #I put this trigger here so if there is only 1 Kasen model, it still runs

    if kasen2_check == True:
    #BLUE FILE
    # open model file
        fin2    = h5py.File(kasen2,'r')

        # frequency in Hz
        nu2    = np.array(fin2['nu'],dtype='d')
        # array of time in seconds
        times2 = np.array(fin2['time'])
        # convert time to days
        times2 = times2/3600.0/24.0

        # specific luminosity (ergs/s/Hz)
        # this is a 2D array, Lnu[times][nu]
        Lnu_all2   = np.array(fin2['Lnu'],dtype='d')

    


    for t_kn in timer:
    #    if t_kn == 1.05: continue
    
        if debug == True:  t_kn = 4.0
        
       # print('working on ',"{:.2f}".format(t_kn))
      #  f2.write(str(t_kn)+" \n")
    
        try:
            # index corresponding to t_kn
            it = bisect.bisect(times,t_kn)
            # spectrum at this epoch
            Lnu = Lnu_all[it,:]
        #    Lnu2 = Lnu_all2[it,:]
        except:
            print("Index out of bounds?")
            continue
    
        # Convert to in Llam (ergs/s/Angstrom)...
        lam0  = c/nu*1e8          # rest-frame wavelength
        lam   = lam0*(1+z_kn)     # redshifted wavelength
        Llam = Lnu*nu**2.0/c/1e8  # Llam
       
        #Makes a dataframe of rest-frame wavelength, redshifted wavelength and flux
    
        df_model_red = pd.DataFrame({'LAMBDA0':lam0, 'LAMBDA':lam, 'Llam':Llam})
    
        #This is where we add the second model and combine it with the first, if there is a second model.
        if (kasen2_check == True): # and (t_kn < 2.05):
            print('working on ',"{:.2f}".format(t_kn), ' with blue and red models')
            # Convert to in Llam (ergs/s/Angstrom)...
            lam02  = c/nu2*1e8      # rest-frame wavelength
            lam2   = lam02*(1+z_kn) # redshifted wavelength
            Llam2 = Lnu2*nu2**2.0/c/1e8  # Llam
          
            df_model_blue = pd.DataFrame({'LAMBDA0':lam02, 'LAMBDA':lam2, 'Llam':Llam2})
    
            df_model_comb = df_model_blue.copy()

            df_model_comb['Llam'] =  df_model_blue['Llam'] + df_model_red['Llam'] 

            df_model_combined = pd.DataFrame({"LAMBDA":df_model_red['LAMBDA'], "Llam":df_model_comb['Llam']})
        else:
            df_model_combined = df_model_red
            print('working on ',"{:.2f}".format(t_kn), ' with red model only')
    
 #   bothfile = """test/both_"""+str(t_kn)
 #   redfile = """test/red_"""+str(t_kn)
 #   bluefile = """test/blue_"""+str(t_kn)
 #   df_model_combined.to_csv(bothfile)
 #   df_model_red.to_csv(redfile)
 #   df_model_blue.to_csv(bluefile)
    
   # df_model_combined.plot('LAMBDA','Llam', color='blue', xlim=[3000.,10000.], title=str(t_kn))
   # plt.show()
        
  #  plt.annotate('t = '+str(t_kn)+' day', (28000, this), horizontalalignment='right', fontsize=22)
    
    #print min(lam), max(lam)
        wavelength_array = np.arange(min(lam0), max(lam0), 1.0)
    
        spec_flux_model = interpolate.interp1d(df_model_combined.LAMBDA, df_model_combined.Llam,bounds_error=False, fill_value=0.,kind='linear')
        spec_flux_model_array = spec_flux_model(wavelength_array)

        df_model_new = pd.DataFrame({'LAMBDA':wavelength_array, 'Llam':spec_flux_model_array})

        #norm = df_model_new['Llam'].median()
        norm = df_model_new[( (df_model_new.LAMBDA > 3000.) & (df_model_new.LAMBDA < 25000.) )].Llam.max()

        df_model_new['normLlam'] = df_model_new['Llam'] / norm

 #   spec_flux_model = interpolate.interp1d(df_model.LAMBDA0, df_model.Llam,bounds_error=False, fill_value=0.,kind='linear')
 #   spec_flux_model_array = spec_flux_model(wavelength_array)

 #   df_model_new = pd.DataFrame({'LAMBDA':wavelength_array, 'Llam':spec_flux_model_array})

    #norm = df_model_new['Llam'].median()
 #   norm = df_model_new[( (df_model_new.LAMBDA > 0.) & (df_model_new.LAMBDA < 12000.) )].Llam.max()
 #   df_model_new['normLlam'] = df_model_new['Llam']/norm

    #ax = df_model_new.plot('LAMBDA','normLlam', c='#000000', label='Model', fontsize=18)
 #   ax = df_model_new.plot('LAMBDA','normLlam', c='#888888', label='Model')
        # Distance to KN in cm...

#HERE IS WHERE WE PRINT THE SEDs
        flux_array = spec_flux_model_array / ((4.*np.pi*(Dlum_cm)**2.))#*(1E-17)) #Flam [ergs/s/cm2/Angstrom]
        nm_array = wavelength_array / 10.
    
        df_model_final = pd.DataFrame({'LAMBDA':nm_array, 'Flam':flux_array})
        outputFile1 = 'sed_'+"{:.2f}".format(z_kn)+"_"+"{:.2f}".format(t_kn)+'.spec'
        outputFile1 = os.path.join(sed_dirname, outputFile1)
  # print(outputFile1)
  # print(df_model_new['LAMBDA'])
        df_model_final.to_csv(outputFile1,mode='w', index = False, sep=' ')

#THIS PART MAKES PLOTS.
#Plots are of the filter bandpasses and the kasen spectrum.
#It also plots the different parts of the Kasen model. 
#You can turn it on by setting plotter = True at the beginning.
        if plotter == True:
            ax = df_model_new.plot('LAMBDA','normLlam', c='#888888', label='Model')    
            for band in bandList:
            #print band
                df_band.plot('LAMBDA', band, c=bandpassColors_dict[band], ax=ax)
              #  df_band2.plot('LAMBDA', band, c=bandpassColors_dict[band], ax=ax)


            title = """%s""" % (model[i])
            plt.title(title, fontsize=16)
            plt.xlim([3000., 25000.])
        #plt.ylim([0.,1.1])
        #ax.legend(loc='upper right', fontsize=14, framealpha=0.5)
        #plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
            ax.set_xlabel('wavelength (observed frame) [$\\AA$]',fontsize=16)
            ax.set_ylabel('Relative $F_{\lambda}$',fontsize=16)
            ax.tick_params(axis = 'both', which = 'major', labelsize = 16)
        #textstr = """$z$=%.3f\n$t$=%.2f days""" % (z_kn, t_kn)
      #  props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
        #ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=14, verticalalignment='top', bbox=props)
            ax.grid(False)
            plt.show()
    
           # ax2 = df_model_blue.plot('LAMBDA','Llam', color='blue', label='light r-process component',xlim=[3000.,30000.])
       # df_model_blue.plot('LAMBDA', 'Llam', ax=ax, xlim=[3000.,30000.], label='light r-process component')
        #    df_model_red.plot('LAMBDA', 'Llam', color='red', ax=ax2, label='heavy r-process component')
        #    df_model_comb.plot('LAMBDA', 'Llam', color='black', ax=ax2, label = 'composite')
        #    plt.show()
        #outputFile = """KNspectrum.%s_z%.3f_a%05.2f.png""" % (fblue, z_kn, t_kn)
           # outputFile = """KNspectrum._z%.3f_a%05.2f.png""" % (z_kn, t_kn)
        #outputFile = 'KNspectrum.z'+str(z_kn)+'_'+str(t_kn)+'.png'
          #  outputFile = os.path.join(png_dirname, outputFile)
    
          #  plt.tight_layout()
          #  plt.savefig(outputFile)



    # Calculate Flam [ergs/s/cm**2/Angstrom] from Llam [ergs/s/Angstrom] and Dlum_cm [cm]...
    #Flam is flux and Llam is luminosity.
        df_model_new['Flam'] = df_model_new['Llam']/(4*np.pi*Dlum_cm*Dlum_cm)

    # Write df_model_new to a temporary output file...
        tempFile = os.path.join(output_dirname,'temp_KNSpectrum.csv')
        df_model_new.to_csv(tempFile, index=False)

   #     run_calc_abmag('u,g,r,i,z,Y', bandpassFile, tempFile, 'LAMBDA', 'Flam', 'Flam', verbose)
        run_calc_abmag('K', bandpassFile, tempFile, 'LAMBDA', 'Flam', 'Flam', verbose)
    
        if debug == True:  break

    print("Yay! All done.")
    f.close()
    #f2.close()
# Out:
# working on model  0
# knova_d1_n10_m0.001_vk0.03_fd1.0_Xlan1e-1.0.h5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 4>()
#       6 print(model[i])
#       8 kasen1 = "/Users/akhalid/Kasen_Kilonova_Models_2017/systematic_kilonova_model_grid/"+model[i]
# ----> 9 Dlum = zToDlum(z_kn)
#      10 Dlum_cm = Mpc_to_cm(Dlum)
#      12 #This is the output light curve file
#
# Input In [8], in zToDlum(z, H0, Om0)
#       3 def zToDlum(z, H0=69.6, Om0=0.286):
#       4     from astropy.cosmology import FlatLambdaCDM
# ----> 5     cosmo = FlatLambdaCDM(H0=H0, Om0=Om0)
#       6     # comoving distance...
#       7     Dcom = cosmo.comoving_distance(z)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/cosmology/flrw.py:2064, in FlatLambdaCDM.__init__(self, H0, Om0, Tcmb0, Neff, m_nu, Ob0, name, meta)
#    2062 def __init__(self, H0, Om0, Tcmb0=0.0*u.K, Neff=3.04, m_nu=0.0*u.eV,
#    2063              Ob0=None, *, name=None, meta=None):
# -> 2064     super().__init__(H0=H0, Om0=Om0, Ode0=0.0, Tcmb0=Tcmb0, Neff=Neff,
#    2065                      m_nu=m_nu, Ob0=Ob0, name=name, meta=meta)
#    2067     # Please see :ref:`astropy-cosmology-fast-integrals` for discussion
#    2068     # about what is being done here.
#    2069     if self._Tcmb0.value == 0:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/cosmology/flrw.py:1435, in FlatFLRWMixin.__init__(self, *args, **kw)
#    1434 def __init__(self, *args, **kw):
# -> 1435     super().__init__(*args, **kw)  # guaranteed not to have `Ode0`
#    1436     # Do some twiddling after the fact to get flatness
#    1437     self._Ode0 = 1.0 - self._Om0 - self._Ogamma0 - self._Onu0
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/cosmology/flrw.py:1541, in LambdaCDM.__init__(self, H0, Om0, Ode0, Tcmb0, Neff, m_nu, Ob0, name, meta)
#    1539 def __init__(self, H0, Om0, Ode0, Tcmb0=0.0*u.K, Neff=3.04, m_nu=0.0*u.eV,
#    1540              Ob0=None, *, name=None, meta=None):
# -> 1541     super().__init__(H0=H0, Om0=Om0, Ode0=Ode0, Tcmb0=Tcmb0, Neff=Neff,
#    1542                      m_nu=m_nu, Ob0=Ob0, name=name, meta=meta)
#    1544     # Please see :ref:`astropy-cosmology-fast-integrals` for discussion
#    1545     # about what is being done here.
#    1546     if self._Tcmb0.value == 0:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/cosmology/flrw.py:135, in FLRW.__init__(self, H0, Om0, Ode0, Tcmb0, Neff, m_nu, Ob0, name, meta)
#     132 super().__init__(name=name, meta=meta)
#     134 # Assign (and validate) Parameters
# --> 135 self.H0 = H0
#     136 self.Om0 = Om0
#     137 self.Ode0 = Ode0
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/cosmology/parameter.py:120, in Parameter.__set__(self, cosmology, value)
#     117     raise AttributeError("can't set attribute")
#     119 # validate value, generally setting units if present
# --> 120 value = self.validate(cosmology, value)
#     121 setattr(cosmology, self._attr_name_private, value)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/cosmology/parameter.py:166, in Parameter.validate(self, cosmology, value)
#     151 def validate(self, cosmology, value):
#     152     """Run the validator on this Parameter.
#     153
#     154     Parameters
#    (...)
#     164         (yes, that parameter order).
#     165     """
# --> 166     return self.fvalidate(cosmology, self, value)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/cosmology/parameter.py:243, in _validate_to_scalar(cosmology, param, value)
#     240 @Parameter.register_validator("scalar")
#     241 def _validate_to_scalar(cosmology, param, value):
#     242     """"""
# --> 243     value = _validate_with_unit(cosmology, param, value)
#     244     if not value.isscalar:
#     245         raise ValueError(f"{param.name} is a non-scalar quantity")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/cosmology/parameter.py:229, in _validate_with_unit(cosmology, param, value)
#     227 if param.unit is not None:
#     228     with u.add_enabled_equivalencies(param.equivalencies):
# --> 229         value = u.Quantity(value, param.unit)
#     230 return value
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:524, in Quantity.__new__(cls, value, unit, dtype, copy, order, subok, ndmin)
#     521     if issubclass(qcls, cls):
#     522         cls = qcls
# --> 524 value = value.view(cls)
#     525 value._set_unit(value_unit)
#     526 if unit is value_unit:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:537, in Quantity.__array_finalize__(self, obj)
#     533 def __array_finalize__(self, obj):
#     534     # Check whether super().__array_finalize should be called
#     535     # (sadly, ndarray.__array_finalize__ is None; we cannot be sure
#     536     # what is above us).
# --> 537     super_array_finalize = super().__array_finalize__
#     538     if super_array_finalize is not None:
#     539         super_array_finalize(obj)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Create Animated Gif
# See https://stackoverflow.com/questions/753190/programmatically-generate-video-or-animated-gif-in-python, as suggested by S. Allam.

# %%
# Define name of the animated GIF to be output...    
kasen_filename = 'blue_red'
outputAnimGif = """KNspectrum.%s_z%.3f.gif""" % (kasen_filename, t_kn)
outputAnimGif = os.path.join(png_dirname, outputAnimGif)

# Identify input png files for the animated GIF...
filenameTemplate = """KNspectrum._z%.3f_a??.??.png""" % (z_kn)
filenameTemplate = os.path.join(png_dirname, filenameTemplate)
#print filenameTemplate
filenames = glob.glob(filenameTemplate)
#for filename in filenames:
#    print filename


# Generate animated GIF...
with imageio.get_writer(outputAnimGif, mode='I', duration=0.1) as writer:
    for filename in filenames:
        print(filename)
        image = imageio.imread(filename)
        writer.append_data(image)

print("""Animated GIF can be found here:  %s""" % (outputAnimGif))
# Out:
# Animated GIF can be found here:  /Users/akhalid/KDC/kasen/PNGs/KNspectrum.blue_red_z12.050.gif

# %% [markdown]
# ## Display Animated Gif
# See https://github.com/ipython/ipython/issues/10045#issuecomment-608641627

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython import display

# Display GIF in Jupyter, CoLab, IPython
with open(outputAnimGif,'rb') as f:
    display.Image(data=f.read(), format='png')
